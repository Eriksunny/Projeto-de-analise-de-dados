# %%
import pandas as pd
import re

# %%
df = pd.read_csv('melbourne_housing_data.csv')

# %%
df.head(10)

# %%
# Mudança de Metodos
# Selecione o comprador 'Nelson'
# Mude o 'Method' dele para 'Pending'

df.loc[df['SellerG'] == 'Nelson', 'Method'] = 'Pending'
df

# %%
# Selecione apenas o (Price, Method, SellerG) para aparecer 

df[['Price', 'Method', 'SellerG']].head(8)
# Out:
#        Price   Method   SellerG
# 0  1490000.0        S    Jellis
# 1  1220000.0        S  Marshall
# 2  1420000.0  Pending    Nelson
# 3  1515000.0        S     Barry
# 4   670000.0  Pending    Nelson
# 5   530000.0        S    Jellis
# 6   540000.0        S     Barry
# 7   715000.0  Pending    Nelson
