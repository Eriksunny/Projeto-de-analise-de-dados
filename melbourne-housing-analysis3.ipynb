# %%
import pandas as pd
import re

# %%
df = pd.read_csv('melbourne_housing_data.csv')

# %%
df.head(5)

# %%
#Mudança de Metodos
#-selecione o comprador 'Ronald'
#-mude o 'Method' dele para 'Pending'

df.loc[df['SellerG'] == 'Ronald', ['Method']] = 'Pending'
df
